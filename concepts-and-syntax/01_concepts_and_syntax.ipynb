# %% [markdown]
# # Syntax & Concepts: Databases and ORM (Peewee)
#
# ### Before Class:
#
# 1. **Read this notebook and attempt each "You Try" section.**
#     - Need help? Check the AI tips or your textbook.
#
# 2. **Complete at least one practice problem from this chapter.**
#     - Problems are ordered from easiest to hardest.
#     - Stuck? Copy and paste the instructions and AI prompt into your preferred AI service for guided help.
#
# 3. **Submit your attempted practice problem code in the "Class Prep Report" on Learning Suite for credit.**
#
# #### Need more explanation? Copy and paste this AI prompt along with any code you have questions about:
# (Double-click the text below, then copy and paste it into your AI service.)
#
# ```
# I am new to Python and just starting to learn coding. I need simple, clear explanations. When I ask a question or show my code, act like my personal tutor: correct mistakes gently, clarify misconceptions, and use easy-to-follow language. Feel free to use examples or metaphors to help me understand. Let me know when I'm doing well or what I need to adjust.
# ```

# %% [markdown]
# ### Chapter Summary
#
# This chapter introduces databases and Object Relational Mapping (ORM), specifically using the **Peewee** library to perform CRUD operations with SQLite.
#
# ORM allows you to work with a database using Python classes instead of raw SQL code.
#
# Key concepts include:
# - Connecting to a database
# - Defining models (which represent tables)
# - Performing **CRUD** operations: Create, Read, Update, and Delete

# %% [markdown]
# ## 1: Connect to SQLite and Define a Model

# %%
from peewee import *

db = SqliteDatabase("students.db")

class Student(Model):
    name = CharField()
    grade = IntegerField()

    class Meta:
        database = db

db.connect()
db.create_tables([Student])

# %% [markdown]
# ### 1.p: You Try
# Connect to a database called `books.db` and define a model `Book` with fields: `title` (CharField) and `pages` (IntegerField).

# %%
# Your code here
from peewee import *

book_db = SqliteDatabase("books.db")

class Book(Model):
    title = CharField()
    pages = IntegerField()

    class Meta:
        database = book_db

book_db.connect()
book_db.create_tables([Student])

# %% [markdown]
# ## 2: Create Records

# %%
s1 = Student.create(name="Alice", grade=90)
s2 = Student.create(name="Bob", grade=85)

# %% [markdown]
# ### 2.p: You Try
# Create two `Book` records in your database with example titles and page counts.

# %%
# Your code here
b1 = Book.create(title="Mein Kampf", pages=110)
b2 = Book.create(title="Midas Touch", pages=111)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/peewee.py:3322, in Database.execute_sql(self, sql, params, commit)
#    3321     cursor = self.cursor()
# -> 3322     cursor.execute(sql, params or ())
#    3323 return cursor
#
# OperationalError: no such table: book
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[34], line 2
#       1 # Your code here
# ----> 2 b1 = Book.create(title="Mein Kampf", pages=110)
#       3 b2 = Book.create(title="Midas Touch", pages=111)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/peewee.py:6748, in Model.create(cls, **query)
#    6745 @classmethod
#    6746 def create(cls, **query):
#    6747     inst = cls(**query)
# -> 6748     inst.save(force_insert=True)
#    6749     return inst
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/peewee.py:6958, in Model.save(self, force_insert, only)
#    6956     rows = self.update(**field_dict).where(self._pk_expr()).execute()
#    6957 elif pk_field is not None:
# -> 6958     pk = self.insert(**field_dict).execute()
#    6959     if pk is not None and (self._meta.auto_increment or
#    6960                            pk_value is None):
#    6961         self._pk = pk
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/peewee.py:2036, in database_required.<locals>.inner(self, database, *args, **kwargs)
#    2033 if not database:
#    2034     raise InterfaceError('Query must be bound to a database in order '
#    2035                          'to call "%s".' % method.__name__)
# -> 2036 return method(self, database, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/peewee.py:2107, in BaseQuery.execute(self, database)
#    2105 @database_required
#    2106 def execute(self, database):
# -> 2107     return self._execute(database)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/peewee.py:2912, in Insert._execute(self, database)
#    2910     self._returning = (self.table._primary_key,)
#    2911 try:
# -> 2912     return super(Insert, self)._execute(database)
#    2913 except self.DefaultValuesException:
#    2914     pass
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/peewee.py:2625, in _WriteQuery._execute(self, database)
#    2623     cursor = self.execute_returning(database)
#    2624 else:
# -> 2625     cursor = database.execute(self)
#    2626 return self.handle_result(database, cursor)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/peewee.py:3330, in Database.execute(self, query, commit, **context_options)
#    3328 ctx = self.get_sql_context(**context_options)
#    3329 sql, params = ctx.sql(query).query()
# -> 3330 return self.execute_sql(sql, params)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/peewee.py:3320, in Database.execute_sql(self, sql, params, commit)
#    3318     __deprecated__('"commit" has been deprecated and is a no-op.')
#    3319 logger.debug((sql, params))
# -> 3320 with __exception_wrapper__:
#    3321     cursor = self.cursor()
#    3322     cursor.execute(sql, params or ())
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/peewee.py:3088, in ExceptionWrapper.__exit__(self, exc_type, exc_value, traceback)
#    3086 new_type = self.exceptions[exc_type.__name__]
#    3087 exc_args = exc_value.args
# -> 3088 reraise(new_type, new_type(exc_value, *exc_args), traceback)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/peewee.py:196, in reraise(tp, value, tb)
#     194 def reraise(tp, value, tb=None):
#     195     if value.__traceback__ is not tb:
# --> 196         raise value.with_traceback(tb)
#     197     raise value
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/peewee.py:3322, in Database.execute_sql(self, sql, params, commit)
#    3320 with __exception_wrapper__:
#    3321     cursor = self.cursor()
# -> 3322     cursor.execute(sql, params or ())
#    3323 return cursor
#
# OperationalError: no such table: book

# %% [markdown]
# ## 3: Read Records

# %%
for student in Student.select():
    print(student.name, student.grade)
# Out:
# Alice 95
# Alice 95
# Alice 90
# Bob 85

# %% [markdown]
# ### 3.p: You Try
# Print all the books in your database, including their title and page count.

# %%
# Your code here

# %% [markdown]
# ## 4: Update Records

# %%
s1.grade = 95
s1.save()
# Out:
# 1

# %% [markdown]
# ### 4.p: You Try
# Change the page count of one of your books and save the update.

# %%
# Your code here

# %% [markdown]
# ## 5: Delete Records

# %%
s2.delete_instance()
# Out:
# 1

# %% [markdown]
# ### 5.p: You Try
# Delete one of your `Book` records from the database.

# %%
# Your code here

# %% [markdown]
# ## Want to Learn More?
#
# If you'd like extra help or more details, you can:
# - **Ask AI**: Use the suggested questions in the `review_with_ai` file.
# - **Read your textbook**: Check the reading guide on Learning Suite beforehand.
# - **Review class practice files**: They contain more detailed examples and explanations, available on Learning Suite.
